# %% [markdown]
# ### Variables in the Boston Housing dataset
# 1. CRIM - per capita crime rate by town
# 2. ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# 3. INDUS - proportion of non-retail business acres per town.
# 4. CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# 5. NOX - nitric oxides concentration (parts per 10 million)
# 6. RM - average number of rooms per dwelling
# 7. AGE - proportion of owner-occupied units built prior to 1940
# 8. DIS - weighted distances to five Boston employment centres
# 9. RAD - index of accessibility to radial highways
# 10. TAX - full-value property-tax rate per USD 10,000
# 11. PTRATIO - pupil-teacher ratio by town
# 12. B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# 13. LSTAT - % lower status of the population
# 14. MEDV - Median value of owner-occupied homes in USD 1000's

# %% [markdown]
# <h2 style = "text-align:center; color:white; font-weight:600; padding:0.5em; background-color: #B02B00; border-radius:25px ; box-shadow: 0 0 20px 0 #ACA7CB; margin-right:3em; margin-bottom:1em">Ⅰ. Import Libraries  </h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.gridspec as gridspec

# %% [markdown]
# <h2 style = "text-align:center; color:white; font-weight:600; padding:0.5em; background-color: #B02B00; border-radius:25px ; box-shadow: 0 0 20px 0 #ACA7CB; margin-right:3em; margin-bottom:1em">ⅠI. Load dataset  </h2>

# %%
bostonHouseFrame= pd.read_csv("housing.data.csv", delimiter="\s+")

# %% [markdown]
# <h3 style = "color : #F06200; font-style:italic; letter-spacing:0.075em;">1.Show data in increase order </h3>

# %%
bostonHouseFrame.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# <h3 style = "color:#51424E ;font-style:italic; letter-spacing:0.075em">2.Show data in decrease order </h3>

# %%
bostonHouseFrame.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9

# %% [markdown]
# <h3 style = "color : #F06200; font-style:italic; letter-spacing:0.075em;">3.Show all data </h3>

# %%
bostonHouseFrame
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %% [markdown]
# <h2 style = "text-align:center; color:white; font-weight:600; padding:0.5em; background-color: #B02B00; border-radius:25px ; box-shadow: 0 0 20px 0 #ACA7CB; margin-right:3em; margin-bottom:1em">ⅠII. Compute some basic statistics  </h2>

# %% [markdown]
# <h3 style = "color : #F06200; font-style:italic; letter-spacing:0.075em;">1.Compute Max Number </h3>

# %%
pd.DataFrame.max(bostonHouseFrame)
# Out:
# CRIM        88.9762
# ZN         100.0000
# INDUS       27.7400
# CHAS         1.0000
# NOX          0.8710
# RM           8.7800
# AGE        100.0000
# DIS         12.1265
# RAD         24.0000
# TAX        711.0000
# PTRATIO     22.0000
# B          396.9000
# LSTAT       37.9700
# MEDV        50.0000
# dtype: float64

# %% [markdown]
# <h3 style = "color:#51424E;font-style:italic; letter-spacing:0.075em">2.Compute Min Number </h3>

# %%
pd.DataFrame.min(bostonHouseFrame)
# Out:
# CRIM         0.00632
# ZN           0.00000
# INDUS        0.46000
# CHAS         0.00000
# NOX          0.38500
# RM           3.56100
# AGE          2.90000
# DIS          1.12960
# RAD          1.00000
# TAX        187.00000
# PTRATIO     12.60000
# B            0.32000
# LSTAT        1.73000
# MEDV         5.00000
# dtype: float64

# %% [markdown]
# <h3 style = "color:#F06200;font-style:italic; letter-spacing:0.075em">3.Compute Mean Number </h3>

# %%
pd.DataFrame.mean(bostonHouseFrame)
# Out:
# CRIM         3.613524
# ZN          11.363636
# INDUS       11.136779
# CHAS         0.069170
# NOX          0.554695
# RM           6.284634
# AGE         68.574901
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.653063
# MEDV        22.532806
# dtype: float64

# %% [markdown]
# <h3 style = "color:#51424E;font-style:italic; letter-spacing:0.075em">4.Compute Median Number </h3>

# %%
pd.DataFrame.median(bostonHouseFrame)
# Out:
# CRIM         0.25651
# ZN           0.00000
# INDUS        9.69000
# CHAS         0.00000
# NOX          0.53800
# RM           6.20850
# AGE         77.50000
# DIS          3.20745
# RAD          5.00000
# TAX        330.00000
# PTRATIO     19.05000
# B          391.44000
# LSTAT       11.36000
# MEDV        21.20000
# dtype: float64

# %% [markdown]
# <h3 style = "text-align:center; text-decoration:underline; color :#B02B00"> Fastest way to describe <strong>min, max, median, mean </strong> </h3>

# %%
bostonHouseFrame.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# <h2 style = "text-align:center; color:white; font-weight:600; padding:0.5em; background-color: #B02B00; border-radius:25px ; box-shadow: 0 0 20px 0 #ACA7CB; margin-right:3em; margin-bottom:1em">ⅠV. Examine the distribution of data  </h2>

# %% [markdown]
# <h3 style = "color : #F06200; font-style:italic; letter-spacing:0.075em;">1.Plot histogram </h3>

# %%
plt.rcParams['figure.figsize'] = [20, 15]
bostonHouseFrame.hist()
plt.show()

# %%
plot = sns.histplot(data=bostonHouseFrame, x = "MEDV",binwidth=3)

# %%
## Creating a customized chart. and giving in figsize and everything.
fig = plt.figure(constrained_layout=True, figsize=(12,8))
## creating a grid of 3 cols and 3 rows.
grid = gridspec.GridSpec(ncols=3, nrows=3, figure=fig)



## Customizing the histogram grid.
ax1 = fig.add_subplot(grid[0, :2])
## Set the title.
ax1.set_title('Histogram')
## plot the histogram.
sns.distplot(bostonHouseFrame.loc[:,"MEDV"], norm_hist=True, ax = ax1)



## Customizing the histogram grid.
ax2 = fig.add_subplot(grid[2, :2])
## Set the title.
ax2.set_title('Histogram')
## plot the histogram.
sns.distplot(bostonHouseFrame.loc[:,"CRIM"], norm_hist=True, ax = ax2)
# Out:
# /Users/bmhuyquoc104/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/bmhuyquoc104/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Histogram'}, xlabel='CRIM', ylabel='Density'>

# %% [markdown]
# <h3 style = "color : #F06200; font-style:italic; letter-spacing:0.075em;">2.Distribution botplot </h3>

# %%
plt.rcParams['figure.figsize'] = [20, 15]
# plot the boxplot to see the outlier of each numerical column
sns.boxplot(data=bostonHouseFrame,orient="v")
plt.title("Bot-Plots Distribution", y = 1,fontsize = 20, pad = 40);

# %%
bostonHouseFrame.plot(kind='box', subplots=True, layout=(4,4), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# <h3 style = "color : #F06200; font-style:italic; letter-spacing:0.075em;">3.Distribution by heatmap (Correlation) </h3>

# %%
correlations = bostonHouseFrame.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1, cmap=plt.cm.PuBu)
fig.colorbar(cax)
ticks = np.arange(0,14,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(bostonHouseFrame.columns)
ax.set_yticklabels(bostonHouseFrame.columns)
plt.show()

# %%
corrMatrix = bostonHouseFrame.corr()
corrMatrix.style.background_gradient(cmap='Greens_r')
# Out:
# <style type="text/css">
# #T_83c40_row0_col0, #T_83c40_row1_col1, #T_83c40_row2_col2, #T_83c40_row3_col3, #T_83c40_row4_col4, #T_83c40_row5_col5, #T_83c40_row6_col6, #T_83c40_row7_col7, #T_83c40_row8_col8, #T_83c40_row9_col9, #T_83c40_row10_col10, #T_83c40_row11_col11, #T_83c40_row12_col12, #T_83c40_row13_col13 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_83c40_row0_col1 {
#   background-color: #1f8742;
#   color: #f1f1f1;
# }
# #T_83c40_row0_col2 {
#   background-color: #aadda4;
#   color: #000000;
# }
# #T_83c40_row0_col3 {
#   background-color: #005622;
#   color: #f1f1f1;
# }
# #T_83c40_row0_col4 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_83c40_row0_col5 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_83c40_row0_col6, #T_83c40_row1_col13 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_83c40_row0_col7, #T_83c40_row11_col4, #T_83c40_row11_col10 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# ...

# %%
## heatmeap to see the correlation between features.
# Generate a mask for the upper triangle (taken from seaborn example gallery)
import numpy as np
mask = np.zeros_like(bostonHouseFrame.corr(), dtype=bool)
mask[np.triu_indices_from(mask)] = True
sns.set_style('whitegrid')
plt.subplots(figsize = (15,12))
sns.heatmap(bostonHouseFrame.corr(),
annot=True,
mask = mask,
cmap = 'Greens_r',
linewidths=.9,
linecolor='white',
fmt='.2g',
center = 0,
square=True)
plt.title("Correlations Among Features", y = 1.03,fontsize = 20, pad = 40);

# %% [markdown]
# <h3 style ="color:red"> Correlated Features: </h3>
# <ul>
#     <li>MEDV, RM, LSTAT are correlated features</li>
#     <li> LSTAT, RM, AGE are correlated features</li>
#     <li> TAZ, INDUS, NDX, AGE correlated features</li>
#     <li> AGE AND NDX are correlated features</li>
#     <li> NDX and INDUS are correlated features </li>
# </ul>
